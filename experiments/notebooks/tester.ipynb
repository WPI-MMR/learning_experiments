# %%
import auto_trainer.utils.safe_wandb

# %%
from auto_trainer import args

# %%
config = args.BaseModelConfiguration().get_args_for_run('test2', 'test2')
# Out:
# Finishing last run (ID:1utrb7gy) before initializing another...
# <br/>Waiting for W&B process to finish, PID 13724<br/>Program ended successfully.
# VBox(children=(Label(value=' 17.45MB of 49.40MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.353298538…
# Find user logs for this run at: <code>/home/agupta/Documents/education/wpi/senior/mqp/learning_experiments/experiments/notebooks/wandb/run-20201115_163945-1utrb7gy/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/agupta/Documents/education/wpi/senior/mqp/learning_experiments/experiments/notebooks/wandb/run-20201115_163945-1utrb7gy/logs/debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 999 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">test2</strong>: <a href="https://wandb.ai/wpi-mmr/solo-rl-experiments/runs/1utrb7gy" target="_blank">https://wandb.ai/wpi-mmr/solo-rl-experiments/runs/1utrb7gy</a><br/>
# ...Successfully finished last run (ID:1utrb7gy). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.10.10<br/>
#                 Syncing run <strong style="color:#cdcd00">test2</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/wpi-mmr/solo-rl-experiments" target="_blank">https://wandb.ai/wpi-mmr/solo-rl-experiments</a><br/>
#                 Run page: <a href="https://wandb.ai/wpi-mmr/solo-rl-experiments/runs/2q4d1g7f" target="_blank">https://wandb.ai/wpi-mmr/solo-rl-experiments/runs/2q4d1g7f</a><br/>
#                 Run data is saved locally in <code>/home/agupta/Documents/education/wpi/senior/mqp/learning_experiments/experiments/notebooks/wandb/run-20201115_164039-2q4d1g7f</code><br/><br/>
#       wandb.init(name=run_name,
#                  project=PROJECT_NAME,
#                  entity=ENTITY,
#                  tags=run_tags,
#                  config=self._parse(),
#                  sync_tensorboard=True)

# %%
config
# Out:
# {'episodes': 10000, 'policy': 'MlpPolicy'}

# %%
import gym
import gym_solo

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2

from gym_solo.envs import solo8v2vanilla
from gym_solo.core import obs
from gym_solo.core import rewards
from gym_solo import testing
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
env_config = solo8v2vanilla.Solo8VanillaConfig()
env = gym.make('solo8vanilla-v0', config=env_config)
env.obs_factory.register_observation(obs.TorsoIMU(env.robot))
env.reward_factory.register_reward(1, rewards.UprightReward(env.robot))

# %%
import wandb
import os 
from stable_baselines.common.callbacks import *

checkpoint = CheckpointCallback(save_freq=10, save_path=os.path.join(wandb.run.dir, 'checkpoints'))

model = PPO2(MlpPolicy, env, verbose=1, tensorboard_log=wandb.run.dir)
model.learn(config.episodes, callback=[checkpoint])
# Out:
# Wrapping the env in a DummyVecEnv.
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/stable_baselines/common/distributions.py:418: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:190: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:198: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:201: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# INFO:tensorflow:Summary name model/pi_fc0/w:0 is illegal; using model/pi_fc0/w_0 instead.
# INFO:tensorflow:Summary name model/pi_fc0/b:0 is illegal; using model/pi_fc0/b_0 instead.
# INFO:tensorflow:Summary name model/vf_fc0/w:0 is illegal; using model/vf_fc0/w_0 instead.
# INFO:tensorflow:Summary name model/vf_fc0/b:0 is illegal; using model/vf_fc0/b_0 instead.
# INFO:tensorflow:Summary name model/pi_fc1/w:0 is illegal; using model/pi_fc1/w_0 instead.
# INFO:tensorflow:Summary name model/pi_fc1/b:0 is illegal; using model/pi_fc1/b_0 instead.
# INFO:tensorflow:Summary name model/vf_fc1/w:0 is illegal; using model/vf_fc1/w_0 instead.
# INFO:tensorflow:Summary name model/vf_fc1/b:0 is illegal; using model/vf_fc1/b_0 instead.
# INFO:tensorflow:Summary name model/vf/w:0 is illegal; using model/vf/w_0 instead.
# INFO:tensorflow:Summary name model/vf/b:0 is illegal; using model/vf/b_0 instead.
# INFO:tensorflow:Summary name model/pi/w:0 is illegal; using model/pi/w_0 instead.
# INFO:tensorflow:Summary name model/pi/b:0 is illegal; using model/pi/b_0 instead.
# INFO:tensorflow:Summary name model/pi/logstd:0 is illegal; using model/pi/logstd_0 instead.
# INFO:tensorflow:Summary name model/q/w:0 is illegal; using model/q/w_0 instead.
# INFO:tensorflow:Summary name model/q/b:0 is illegal; using model/q/b_0 instead.
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:206: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:240: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:242: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/stable_baselines/common/base_class.py:1169: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:285: The name tf.RunOptions is deprecated. Please use tf.compat.v1.RunOptions instead.
#
# WARNING:tensorflow:From /home/agupta/Documents/education/wpi/senior/mqp/venv-tf1.15/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:286: The name tf.RunMetadata is deprecated. Please use tf.compat.v1.RunMetadata instead.
#
# -------------------------------------
# | approxkl           | 0.0010356765 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.184        |
# | fps                | 184          |
# | n_updates          | 1            |
# | policy_entropy     | 17.02823     |
# | policy_loss        | -0.01095861  |
# | serial_timesteps   | 128          |
# | time_elapsed       | 0.000444     |
# | total_timesteps    | 128          |
# | value_loss         | 0.0047203484 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00039228954 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.728         |
# | fps                | 583           |
# | n_updates          | 2             |
# | policy_entropy     | 17.027578     |
# | policy_loss        | -0.0070876637 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 0.696         |
# | total_timesteps    | 256           |
# | value_loss         | 0.001257071   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00034847594 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.143        |
# | fps                | 621           |
# | n_updates          | 3             |
# | policy_entropy     | 17.029446     |
# | policy_loss        | -0.0048430553 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 0.916         |
# | total_timesteps    | 384           |
# | value_loss         | 0.0013133999  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00021891796 |
# | clipfrac           | 0.0           |
# | explained_variance | -4.62         |
# | fps                | 512           |
# | n_updates          | 4             |
# | policy_entropy     | 17.028913     |
# | policy_loss        | -0.004749616  |
# | serial_timesteps   | 512           |
# | time_elapsed       | 1.12          |
# | total_timesteps    | 512           |
# | value_loss         | 0.0003903932  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 7.335571e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | -6.74        |
# | fps                | 445          |
# | n_updates          | 5            |
# | policy_entropy     | 17.028475    |
# | policy_loss        | -0.002924644 |
# | serial_timesteps   | 640          |
# | time_elapsed       | 1.38         |
# | total_timesteps    | 640          |
# | value_loss         | 7.472703e-05 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 6.1617495e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -2.37         |
# | fps                | 582           |
# | n_updates          | 6             |
# | policy_entropy     | 17.024506     |
# | policy_loss        | -0.0022362927 |
# | serial_timesteps   | 768           |
# | time_elapsed       | 1.66          |
# | total_timesteps    | 768           |
# | value_loss         | 2.037688e-05  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014457821 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.903        |
# | fps                | 639           |
# | n_updates          | 7             |
# | policy_entropy     | 17.031649     |
# | policy_loss        | -0.0049577137 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 1.89          |
# | total_timesteps    | 896           |
# | value_loss         | 9.176792e-05  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.880475e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -4.41         |
# | fps                | 502           |
# | n_updates          | 8             |
# | policy_entropy     | 17.035696     |
# | policy_loss        | -0.0025864923 |
# | serial_timesteps   | 1024          |
# | time_elapsed       | 2.09          |
# | total_timesteps    | 1024          |
# | value_loss         | 1.7221477e-05 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0016692444  |
# | clipfrac           | 0.015625      |
# | explained_variance | 0.477         |
# | fps                | 609           |
# | n_updates          | 9             |
# | policy_entropy     | 17.033457     |
# | policy_loss        | -0.015066393  |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 2.34          |
# | total_timesteps    | 1152          |
# | value_loss         | 0.00048044597 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002495765  |
# | clipfrac           | 0.0           |
# | explained_variance | -2.77         |
# | fps                | 552           |
# | n_updates          | 10            |
# | policy_entropy     | 17.035112     |
# | policy_loss        | -0.0043261703 |
# | serial_timesteps   | 1280          |
# | time_elapsed       | 2.55          |
# | total_timesteps    | 1280          |
# | value_loss         | 0.00010741967 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.656604e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -8.24         |
# | fps                | 580           |
# | n_updates          | 11            |
# | policy_entropy     | 17.043797     |
# | policy_loss        | -0.0022610144 |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 2.79          |
# | total_timesteps    | 1408          |
# | value_loss         | 8.308609e-05  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.6525338e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -6.59         |
# | fps                | 606           |
# | n_updates          | 12            |
# | policy_entropy     | 17.049488     |
# | policy_loss        | -0.0010288158 |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 3.01          |
# | total_timesteps    | 1536          |
# | value_loss         | 1.5309117e-05 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.000651038   |
# | clipfrac           | 0.0           |
# | explained_variance | -2.15         |
# | fps                | 556           |
# | n_updates          | 13            |
# | policy_entropy     | 17.044554     |
# | policy_loss        | -0.009719485  |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 3.22          |
# | total_timesteps    | 1664          |
# | value_loss         | 0.00037247228 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005460364  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0339        |
# | fps                | 517           |
# | n_updates          | 14            |
# | policy_entropy     | 17.042706     |
# | policy_loss        | -0.0047013825 |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 3.45          |
# | total_timesteps    | 1792          |
# | value_loss         | 2.2512057e-05 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00032180597 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.122        |
# | fps                | 612           |
# | n_updates          | 15            |
# | policy_entropy     | 17.044352     |
# | policy_loss        | -0.0022924312 |
# | serial_timesteps   | 1920          |
# | time_elapsed       | 3.7           |
# | total_timesteps    | 1920          |
# | value_loss         | 8.924968e-05  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.618334e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -3.12         |
# | fps                | 620           |
# | n_updates          | 16            |
# | policy_entropy     | 17.049416     |
# | policy_loss        | -0.002052608  |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 3.91          |
# | total_timesteps    | 2048          |
# | value_loss         | 4.4103526e-05 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.5800753e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -4.34         |
# | fps                | 595           |
# | n_updates          | 17            |
# | policy_entropy     | 17.056675     |
# | policy_loss        | -0.002949374  |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 4.12          |
# | total_timesteps    | 2176          |
# | value_loss         | 1.786217e-05  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0001958545  |
# | clipfrac           | 0.0           |
# | explained_variance | -4.78         |
# | fps                | 608           |
# | n_updates          | 18            |
# | policy_entropy     | 17.061958     |
# | policy_loss        | -0.0045655365 |
# | serial_timesteps   | 2304          |
# | time_elapsed       | 4.34          |
# | total_timesteps    | 2304          |
# | value_loss         | 1.4164076e-05 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00036364654 |
# | clipfrac           | 0.0           |
# | explained_variance | -7.21         |
# | fps                | 554           |
# | n_updates          | 19            |
# | policy_entropy     | 17.064825     |
# | policy_loss        | -0.004311705  |
# | serial_timesteps   | 2432          |
# | time_elapsed       | 4.55          |
# | total_timesteps    | 2432          |
# | value_loss         | 8.2467095e-06 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.692489e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -2.28         |
# | fps                | 562           |
# | n_updates          | 20            |
# | policy_entropy     | 17.064379     |
# | policy_loss        | -0.0035639505 |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 4.78          |
# | total_timesteps    | 2560          |
# | value_loss         | 2.6251296e-06 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014127657 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.145        |
# | fps                | 608           |
# | n_updates          | 21            |
# | policy_entropy     | 17.063128     |
# | policy_loss        | -0.0030295937 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 5.01          |
# | total_timesteps    | 2688          |
# | value_loss         | 7.4553063e-06 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.000280488   |
# | clipfrac           | 0.0           |
# | explained_variance | -4.47         |
# | fps                | 617           |
# | n_updates          | 22            |
# | policy_entropy     | 17.065746     |
# | policy_loss        | -0.003853527  |
# | serial_timesteps   | 2816          |
# | time_elapsed       | 5.22          |
# | total_timesteps    | 2816          |
# | value_loss         | 7.2756493e-06 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00037624722 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.943        |
# | fps                | 327           |
# | n_updates          | 23            |
# | policy_entropy     | 17.069513     |
# | policy_loss        | -0.0051057665 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 5.43          |
# | total_timesteps    | 2944          |
# | value_loss         | 9.2752025e-06 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0001616267  |
# | clipfrac           | 0.0           |
# | explained_variance | -2.04         |
# | fps                | 519           |
# | n_updates          | 24            |
# | policy_entropy     | 17.069096     |
# | policy_loss        | -0.0030902647 |
# | serial_timesteps   | 3072          |
# | time_elapsed       | 5.82          |
# | total_timesteps    | 3072          |
# | value_loss         | 2.577985e-06  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024269345 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.195         |
# | fps                | 559           |
# | n_updates          | 25            |
# | policy_entropy     | 17.070953     |
# | policy_loss        | -0.004423977  |
# | serial_timesteps   | 3200          |
# | time_elapsed       | 6.07          |
# | total_timesteps    | 3200          |
# | value_loss         | 0.00018573811 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00043105666 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0867       |
# | fps                | 516           |
# | n_updates          | 26            |
# | policy_entropy     | 17.070276     |
# | policy_loss        | -0.0069367276 |
# | serial_timesteps   | 3328          |
# | time_elapsed       | 6.3           |
# | total_timesteps    | 3328          |
# | value_loss         | 6.333953e-05  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0018278027  |
# | clipfrac           | 0.021484375   |
# | explained_variance | 0.48          |
# | fps                | 507           |
# | n_updates          | 27            |
# | policy_entropy     | 17.067371     |
# | policy_loss        | -0.017603882  |
# | serial_timesteps   | 3456          |
# | time_elapsed       | 6.55          |
# | total_timesteps    | 3456          |
# | value_loss         | 0.00044871098 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.004838116   |
# | clipfrac           | 0.05859375    |
# | explained_variance | 0.29          |
# | fps                | 506           |
# | n_updates          | 28            |
# | policy_entropy     | 17.065903     |
# | policy_loss        | -0.00792202   |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 6.8           |
# | total_timesteps    | 3584          |
# | value_loss         | 0.00090192485 |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0031929861 |
# | clipfrac           | 0.033203125  |
# | explained_variance | -0.496       |
# | fps                | 528          |
# | n_updates          | 29           |
# | policy_entropy     | 17.065527    |
# | policy_loss        | -0.014879193 |
# | serial_timesteps   | 3712         |
# | time_elapsed       | 7.06         |
# | total_timesteps    | 3712         |
# | value_loss         | 0.006158742  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.006082836  |
# | clipfrac           | 0.080078125  |
# | explained_variance | 0.286        |
# | fps                | 554          |
# | n_updates          | 30           |
# | policy_entropy     | 17.06672     |
# | policy_loss        | -0.012308232 |
# | serial_timesteps   | 3840         |
# | time_elapsed       | 7.3          |
# | total_timesteps    | 3840         |
# | value_loss         | 0.022050293  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0015511978 |
# | clipfrac           | 0.005859375  |
# | explained_variance | -0.362       |
# | fps                | 547          |
# | n_updates          | 31           |
# | policy_entropy     | 17.07178     |
# | policy_loss        | -0.010088952 |
# | serial_timesteps   | 3968         |
# | time_elapsed       | 7.53         |
# | total_timesteps    | 3968         |
# | value_loss         | 0.4763136    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0046730028 |
# | clipfrac           | 0.05078125   |
# | explained_variance | 0.575        |
# | fps                | 530          |
# | n_updates          | 32           |
# | policy_entropy     | 17.076216    |
# | policy_loss        | -0.022386873 |
# | serial_timesteps   | 4096         |
# | time_elapsed       | 7.77         |
# | total_timesteps    | 4096         |
# | value_loss         | 0.38129076   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.002533987  |
# | clipfrac           | 0.029296875  |
# | explained_variance | 0.471        |
# | fps                | 561          |
# | n_updates          | 33           |
# | policy_entropy     | 17.077585    |
# | policy_loss        | -0.014607124 |
# | serial_timesteps   | 4224         |
# | time_elapsed       | 8.01         |
# | total_timesteps    | 4224         |
# | value_loss         | 0.013205593  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0018296768  |
# | clipfrac           | 0.015625      |
# | explained_variance | -0.852        |
# | fps                | 562           |
# | n_updates          | 34            |
# | policy_entropy     | 17.0805       |
# | policy_loss        | -0.0104926545 |
# | serial_timesteps   | 4352          |
# | time_elapsed       | 8.24          |
# | total_timesteps    | 4352          |
# | value_loss         | 0.010249709   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.004460228  |
# | clipfrac           | 0.05859375   |
# | explained_variance | 0.143        |
# | fps                | 589          |
# | n_updates          | 35           |
# | policy_entropy     | 17.08308     |
# | policy_loss        | -0.014502458 |
# | serial_timesteps   | 4480         |
# | time_elapsed       | 8.47         |
# | total_timesteps    | 4480         |
# | value_loss         | 0.01122824   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0007614975 |
# | clipfrac           | 0.0078125    |
# | explained_variance | -0.527       |
# | fps                | 584          |
# | n_updates          | 36           |
# | policy_entropy     | 17.087954    |
# | policy_loss        | -0.009373498 |
# | serial_timesteps   | 4608         |
# | time_elapsed       | 8.69         |
# | total_timesteps    | 4608         |
# | value_loss         | 0.003614008  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0006348101 |
# | clipfrac           | 0.00390625   |
# | explained_variance | -1.73        |
# | fps                | 546          |
# | n_updates          | 37           |
# | policy_entropy     | 17.096344    |
# | policy_loss        | -0.008623423 |
# | serial_timesteps   | 4736         |
# | time_elapsed       | 8.91         |
# | total_timesteps    | 4736         |
# | value_loss         | 0.0017225848 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0004735026 |
# | clipfrac           | 0.001953125  |
# | explained_variance | -0.541       |
# | fps                | 535          |
# | n_updates          | 38           |
# | policy_entropy     | 17.099821    |
# | policy_loss        | -0.004532059 |
# | serial_timesteps   | 4864         |
# | time_elapsed       | 9.14         |
# | total_timesteps    | 4864         |
# | value_loss         | 0.000796178  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00011116529 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.872        |
# | fps                | 535           |
# | n_updates          | 39            |
# | policy_entropy     | 17.105238     |
# | policy_loss        | -0.0013861886 |
# | serial_timesteps   | 4992          |
# | time_elapsed       | 9.38          |
# | total_timesteps    | 4992          |
# | value_loss         | 0.00051951583 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00040854973 |
# | clipfrac           | 0.001953125   |
# | explained_variance | -6.32         |
# | fps                | 576           |
# | n_updates          | 40            |
# | policy_entropy     | 17.111433     |
# | policy_loss        | -0.0072513903 |
# | serial_timesteps   | 5120          |
# | time_elapsed       | 9.62          |
# | total_timesteps    | 5120          |
# | value_loss         | 0.0004517553  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00051627884 |
# | clipfrac           | 0.00390625    |
# | explained_variance | -2.72         |
# | fps                | 537           |
# | n_updates          | 41            |
# | policy_entropy     | 17.115969     |
# | policy_loss        | -0.0063083665 |
# | serial_timesteps   | 5248          |
# | time_elapsed       | 9.85          |
# | total_timesteps    | 5248          |
# | value_loss         | 0.00050935155 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0020158454  |
# | clipfrac           | 0.021484375   |
# | explained_variance | 0.44          |
# | fps                | 574           |
# | n_updates          | 42            |
# | policy_entropy     | 17.114063     |
# | policy_loss        | -0.008317437  |
# | serial_timesteps   | 5376          |
# | time_elapsed       | 10.1          |
# | total_timesteps    | 5376          |
# | value_loss         | 0.00020964074 |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0020678416 |
# | clipfrac           | 0.01953125   |
# | explained_variance | 0.312        |
# | fps                | 480          |
# | n_updates          | 43           |
# | policy_entropy     | 17.111338    |
# | policy_loss        | -0.005643096 |
# | serial_timesteps   | 5504         |
# | time_elapsed       | 10.3         |
# | total_timesteps    | 5504         |
# | value_loss         | 0.0008792779 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0012938762 |
# | clipfrac           | 0.01171875   |
# | explained_variance | -0.391       |
# | fps                | 430          |
# | n_updates          | 44           |
# | policy_entropy     | 17.108416    |
# | policy_loss        | -0.013049736 |
# | serial_timesteps   | 5632         |
# | time_elapsed       | 10.6         |
# | total_timesteps    | 5632         |
# | value_loss         | 0.0006458118 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0010960076  |
# | clipfrac           | 0.01171875    |
# | explained_variance | 0.196         |
# | fps                | 570           |
# | n_updates          | 45            |
# | policy_entropy     | 17.101418     |
# | policy_loss        | -0.0090070795 |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 10.9          |
# | total_timesteps    | 5760          |
# | value_loss         | 0.00024183966 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0013711913  |
# | clipfrac           | 0.0078125     |
# | explained_variance | -2.29         |
# | fps                | 529           |
# | n_updates          | 46            |
# | policy_entropy     | 17.09589      |
# | policy_loss        | -0.014558097  |
# | serial_timesteps   | 5888          |
# | time_elapsed       | 11.1          |
# | total_timesteps    | 5888          |
# | value_loss         | 0.00018905783 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0013620793  |
# | clipfrac           | 0.015625      |
# | explained_variance | -1.02         |
# | fps                | 587           |
# | n_updates          | 47            |
# | policy_entropy     | 17.093822     |
# | policy_loss        | -0.0124852015 |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 11.3          |
# | total_timesteps    | 6016          |
# | value_loss         | 0.00011597672 |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0039256862 |
# | clipfrac           | 0.048828125  |
# | explained_variance | 0.234        |
# | fps                | 566          |
# | n_updates          | 48           |
# | policy_entropy     | 17.090136    |
# | policy_loss        | -0.01841288  |
# | serial_timesteps   | 6144         |
# | time_elapsed       | 11.6         |
# | total_timesteps    | 6144         |
# | value_loss         | 0.0060607344 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0037464446 |
# | clipfrac           | 0.037109375  |
# | explained_variance | -0.0512      |
# | fps                | 294          |
# | n_updates          | 49           |
# | policy_entropy     | 17.085571    |
# | policy_loss        | -0.021803755 |
# | serial_timesteps   | 6272         |
# | time_elapsed       | 11.8         |
# | total_timesteps    | 6272         |
# | value_loss         | 0.001033594  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0011072161 |
# | clipfrac           | 0.01171875   |
# | explained_variance | -0.368       |
# | fps                | 590          |
# | n_updates          | 50           |
# | policy_entropy     | 17.085068    |
# | policy_loss        | -0.011509541 |
# | serial_timesteps   | 6400         |
# | time_elapsed       | 12.2         |
# | total_timesteps    | 6400         |
# | value_loss         | 0.0017813088 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0007826029  |
# | clipfrac           | 0.00390625    |
# | explained_variance | -0.0677       |
# | fps                | 556           |
# | n_updates          | 51            |
# | policy_entropy     | 17.086535     |
# | policy_loss        | -0.0053865784 |
# | serial_timesteps   | 6528          |
# | time_elapsed       | 12.4          |
# | total_timesteps    | 6528          |
# | value_loss         | 0.00015190971 |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0008639976 |
# | clipfrac           | 0.00390625   |
# | explained_variance | -13.4        |
# | fps                | 628          |
# | n_updates          | 52           |
# | policy_entropy     | 17.092197    |
# | policy_loss        | -0.009670829 |
# | serial_timesteps   | 6656         |
# | time_elapsed       | 12.7         |
# | total_timesteps    | 6656         |
# | value_loss         | 4.725782e-05 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0016967587 |
# | clipfrac           | 0.017578125  |
# | explained_variance | -2.05        |
# | fps                | 576          |
# | n_updates          | 53           |
# | policy_entropy     | 17.102844    |
# | policy_loss        | -0.011499055 |
# | serial_timesteps   | 6784         |
# | time_elapsed       | 12.9         |
# | total_timesteps    | 6784         |
# | value_loss         | 4.359549e-05 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0017096099  |
# | clipfrac           | 0.01171875    |
# | explained_variance | 0.352         |
# | fps                | 547           |
# | n_updates          | 54            |
# | policy_entropy     | 17.107502     |
# | policy_loss        | -0.0055237487 |
# | serial_timesteps   | 6912          |
# | time_elapsed       | 13.1          |
# | total_timesteps    | 6912          |
# | value_loss         | 0.0014962322  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.001674299  |
# | clipfrac           | 0.015625     |
# | explained_variance | -0.372       |
# | fps                | 628          |
# | n_updates          | 55           |
# | policy_entropy     | 17.10748     |
# | policy_loss        | -0.008848062 |
# | serial_timesteps   | 7040         |
# | time_elapsed       | 13.3         |
# | total_timesteps    | 7040         |
# | value_loss         | 0.0017410716 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.003174359   |
# | clipfrac           | 0.029296875   |
# | explained_variance | 0.455         |
# | fps                | 551           |
# | n_updates          | 56            |
# | policy_entropy     | 17.108805     |
# | policy_loss        | -0.0140477335 |
# | serial_timesteps   | 7168          |
# | time_elapsed       | 13.5          |
# | total_timesteps    | 7168          |
# | value_loss         | 0.0006064564  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0009587795 |
# | clipfrac           | 0.00390625   |
# | explained_variance | -0.687       |
# | fps                | 608          |
# | n_updates          | 57           |
# | policy_entropy     | 17.112835    |
# | policy_loss        | -0.009321637 |
# | serial_timesteps   | 7296         |
# | time_elapsed       | 13.8         |
# | total_timesteps    | 7296         |
# | value_loss         | 0.0018828314 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0051988238 |
# | clipfrac           | 0.0546875    |
# | explained_variance | 0.268        |
# | fps                | 588          |
# | n_updates          | 58           |
# | policy_entropy     | 17.113064    |
# | policy_loss        | -0.016316758 |
# | serial_timesteps   | 7424         |
# | time_elapsed       | 14           |
# | total_timesteps    | 7424         |
# | value_loss         | 0.0006286398 |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.002604823 |
# | clipfrac           | 0.0234375   |
# | explained_variance | 0.269       |
# | fps                | 540         |
# | n_updates          | 59          |
# | policy_entropy     | 17.11659    |
# | policy_loss        | -0.01188936 |
# | serial_timesteps   | 7552        |
# | time_elapsed       | 14.2        |
# | total_timesteps    | 7552        |
# | value_loss         | 0.00839432  |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.0013583584 |
# | clipfrac           | 0.009765625  |
# | explained_variance | 0.417        |
# | fps                | 573          |
# | n_updates          | 60           |
# | policy_entropy     | 17.12239     |
# | policy_loss        | -0.010683275 |
# | serial_timesteps   | 7680         |
# | time_elapsed       | 14.4         |
# | total_timesteps    | 7680         |
# | value_loss         | 0.0013376632 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00092521275 |
# | clipfrac           | 0.009765625   |
# | explained_variance | -6.91         |
# | fps                | 604           |
# | n_updates          | 61            |
# | policy_entropy     | 17.120546     |
# | policy_loss        | -0.013459281  |
# | serial_timesteps   | 7808          |
# | time_elapsed       | 14.7          |
# | total_timesteps    | 7808          |
# | value_loss         | 0.0005349851  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.002227448  |
# | clipfrac           | 0.021484375  |
# | explained_variance | -0.0601      |
# | fps                | 574          |
# | n_updates          | 62           |
# | policy_entropy     | 17.111748    |
# | policy_loss        | -0.012956357 |
# | serial_timesteps   | 7936         |
# | time_elapsed       | 14.9         |
# | total_timesteps    | 7936         |
# | value_loss         | 0.0019095854 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0013226565  |
# | clipfrac           | 0.00390625    |
# | explained_variance | -0.0191       |
# | fps                | 553           |
# | n_updates          | 63            |
# | policy_entropy     | 17.105946     |
# | policy_loss        | -0.0120452605 |
# | serial_timesteps   | 8064          |
# | time_elapsed       | 15.1          |
# | total_timesteps    | 8064          |
# | value_loss         | 0.28014776    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.003990108  |
# | clipfrac           | 0.046875     |
# | explained_variance | -2.46        |
# | fps                | 578          |
# | n_updates          | 64           |
# | policy_entropy     | 17.10185     |
# | policy_loss        | -0.012246525 |
# | serial_timesteps   | 8192         |
# | time_elapsed       | 15.3         |
# | total_timesteps    | 8192         |
# | value_loss         | 0.10016542   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0045315684 |
# | clipfrac           | 0.064453125  |
# | explained_variance | -1.78        |
# | fps                | 621          |
# | n_updates          | 65           |
# | policy_entropy     | 17.09848     |
# | policy_loss        | -0.011800442 |
# | serial_timesteps   | 8320         |
# | time_elapsed       | 15.6         |
# | total_timesteps    | 8320         |
# | value_loss         | 0.0057707843 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.008469601  |
# | clipfrac           | 0.099609375  |
# | explained_variance | 0.142        |
# | fps                | 613          |
# | n_updates          | 66           |
# | policy_entropy     | 17.099459    |
# | policy_loss        | -0.025493018 |
# | serial_timesteps   | 8448         |
# | time_elapsed       | 15.8         |
# | total_timesteps    | 8448         |
# | value_loss         | 0.34148765   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0033326573 |
# | clipfrac           | 0.04296875   |
# | explained_variance | 0.527        |
# | fps                | 621          |
# | n_updates          | 67           |
# | policy_entropy     | 17.09971     |
# | policy_loss        | -0.01103518  |
# | serial_timesteps   | 8576         |
# | time_elapsed       | 16           |
# | total_timesteps    | 8576         |
# | value_loss         | 0.093228854  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0045295013 |
# | clipfrac           | 0.064453125  |
# | explained_variance | -2.07        |
# | fps                | 591          |
# | n_updates          | 68           |
# | policy_entropy     | 17.098024    |
# | policy_loss        | -0.016398579 |
# | serial_timesteps   | 8704         |
# | time_elapsed       | 16.2         |
# | total_timesteps    | 8704         |
# | value_loss         | 0.03689138   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0015501349 |
# | clipfrac           | 0.017578125  |
# | explained_variance | -3.32        |
# | fps                | 634          |
# | n_updates          | 69           |
# | policy_entropy     | 17.095942    |
# | policy_loss        | -0.012017026 |
# | serial_timesteps   | 8832         |
# | time_elapsed       | 16.4         |
# | total_timesteps    | 8832         |
# | value_loss         | 0.046916433  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0008747616 |
# | clipfrac           | 0.009765625  |
# | explained_variance | -2.15        |
# | fps                | 619          |
# | n_updates          | 70           |
# | policy_entropy     | 17.095255    |
# | policy_loss        | -0.008056385 |
# | serial_timesteps   | 8960         |
# | time_elapsed       | 16.6         |
# | total_timesteps    | 8960         |
# | value_loss         | 0.013621563  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0005842885 |
# | clipfrac           | 0.0          |
# | explained_variance | -3.98        |
# | fps                | 599          |
# | n_updates          | 71           |
# | policy_entropy     | 17.096825    |
# | policy_loss        | -0.007565623 |
# | serial_timesteps   | 9088         |
# | time_elapsed       | 16.8         |
# | total_timesteps    | 9088         |
# | value_loss         | 0.0022920456 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0005171473  |
# | clipfrac           | 0.001953125   |
# | explained_variance | -0.457        |
# | fps                | 625           |
# | n_updates          | 72            |
# | policy_entropy     | 17.095507     |
# | policy_loss        | -0.0057775797 |
# | serial_timesteps   | 9216          |
# | time_elapsed       | 17            |
# | total_timesteps    | 9216          |
# | value_loss         | 0.0010309429  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00036600675 |
# | clipfrac           | 0.0           |
# | explained_variance | -2.6          |
# | fps                | 582           |
# | n_updates          | 73            |
# | policy_entropy     | 17.1016       |
# | policy_loss        | -0.0063281734 |
# | serial_timesteps   | 9344          |
# | time_elapsed       | 17.2          |
# | total_timesteps    | 9344          |
# | value_loss         | 0.00094330206 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005578373  |
# | clipfrac           | 0.00390625    |
# | explained_variance | 0.542         |
# | fps                | 589           |
# | n_updates          | 74            |
# | policy_entropy     | 17.111013     |
# | policy_loss        | -0.008126482  |
# | serial_timesteps   | 9472          |
# | time_elapsed       | 17.5          |
# | total_timesteps    | 9472          |
# | value_loss         | 0.00054087705 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0021582358  |
# | clipfrac           | 0.0234375     |
# | explained_variance | 0.246         |
# | fps                | 557           |
# | n_updates          | 75            |
# | policy_entropy     | 17.11016      |
# | policy_loss        | -0.012283485  |
# | serial_timesteps   | 9600          |
# | time_elapsed       | 17.7          |
# | total_timesteps    | 9600          |
# | value_loss         | 0.00088243093 |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0019514788 |
# | clipfrac           | 0.015625     |
# | explained_variance | -1.57        |
# | fps                | 583          |
# | n_updates          | 76           |
# | policy_entropy     | 17.104208    |
# | policy_loss        | -0.010054254 |
# | serial_timesteps   | 9728         |
# | time_elapsed       | 17.9         |
# | total_timesteps    | 9728         |
# | value_loss         | 0.0050376137 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0024769867 |
# | clipfrac           | 0.029296875  |
# | explained_variance | -1.06        |
# | fps                | 619          |
# | n_updates          | 77           |
# | policy_entropy     | 17.102995    |
# | policy_loss        | -0.010363128 |
# | serial_timesteps   | 9856         |
# | time_elapsed       | 18.1         |
# | total_timesteps    | 9856         |
# | value_loss         | 0.010639974  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.002800988  |
# | clipfrac           | 0.03125      |
# | explained_variance | -0.0864      |
# | fps                | 589          |
# | n_updates          | 78           |
# | policy_entropy     | 17.101055    |
# | policy_loss        | -0.009257621 |
# | serial_timesteps   | 9984         |
# | time_elapsed       | 18.3         |
# | total_timesteps    | 9984         |
# | value_loss         | 0.009316039  |
# -------------------------------------

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.15.4'

# %%
# !pip freeze
